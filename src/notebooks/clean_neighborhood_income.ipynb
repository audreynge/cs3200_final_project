# %%
import pandas as pd
from pathlib import Path

# %%
df = pd.read_csv(Path('../../data/raw/boston_neighborhood_income.csv'))
df
# Out:
#                NEIGHBORHOOD  MEDIAN_HOUSEHOLD_INCOME  TOTAL_HOUSEHOLDS  \
# 0                   Allston                    73337             11158
# 1                  Back Bay                   128685             10166
# 2               Beacon Hill                   147117              5504
# 3                  Brighton                    88223             24644
# 4               Charlestown                   159859              9010
# 5                 Chinatown                    49470              3063
# 6                Dorchester                    73213             45798
# 7                  Downtown                   127335              6152
# 8               East Boston                    91205             18266
# 9                    Fenway                    49540             14674
# 10                Hyde Park                   103651             12527
# 11            Jamaica Plain                   124824             18421
# ...

# %%
# rename cols
new_cols = [
    "neighborhood",
    "median_income",
    "total_households",
    "income_lt_15000",
    "pct_lt_15000",
    "income_15000_24999",
    "pct_15000_24999",
    "income_25000_34999",
    "pct_25000_34999",
    "income_35000_49999",
    "pct_35000_49999",
    "income_50000_74999",
    "pct_50000_74999",
    "income_75000_99999",
    "pct_75000_99999",
    "income_100000_149999",
    "pct_100000_149999",
    "income_150000_plus",
    "pct_150000_plus"
]

df.columns = new_cols
df
# Out:
#                neighborhood  median_income  total_households  income_lt_15000  \
# 0                   Allston          73337             11158             1852
# 1                  Back Bay         128685             10166             1183
# 2               Beacon Hill         147117              5504              371
# 3                  Brighton          88223             24644             2993
# 4               Charlestown         159859              9010              546
# 5                 Chinatown          49470              3063              629
# 6                Dorchester          73213             45798             6709
# 7                  Downtown         127335              6152             1037
# 8               East Boston          91205             18266             1894
# 9                    Fenway          49540             14674             3803
# 10                Hyde Park         103651             12527              953
# ...
