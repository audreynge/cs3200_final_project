# %%
import pandas as pd
from pathlib import Path

# %%
df = pd.read_csv(Path('../../data/raw/rail_ridership.csv'))
df

"""
direction_id - 0 = outbound, 1 = inbound
"""
# Out:
# '\ndirection_id - 0 = outbound, 1 = inbound\n'

# %%
# drop unecessary cols
df = df.drop(columns=['mode', 'route_name', 'day_type_id', 'stop_name', 'ObjectId'], axis=1)

# %%
df
# Out:
#          season route_id  direction_id day_type_name  time_period_id  \
# 0     Fall 2019    Green             0       weekday  time_period_01
# 1     Fall 2019    Green             0       weekday  time_period_01
# 2     Fall 2019    Green             0       weekday  time_period_01
# 3     Fall 2019    Green             0       weekday  time_period_01
# 4     Fall 2019    Green             0       weekday  time_period_01
# ...         ...      ...           ...           ...             ...
# 7915  Fall 2017      Red             0      saturday  time_period_10
# 7916  Fall 2017      Red             0      saturday  time_period_10
# 7917  Fall 2017      Red             0      saturday  time_period_10
# 7918  Fall 2017      Red             0      saturday  time_period_10
# 7919  Fall 2017      Red             0      saturday  time_period_10
#
#         time_period_name      stop_id  total_ons  total_offs  \
# 0     VERY_EARLY_MORNING  place-alsgr          0          17
# ...

# %%
df.isnull().sum()
# Out:
# mode                   0
# season                 0
# route_id               0
# direction_id           0
# day_type_name          0
# time_period_id         0
# time_period_name       0
# stop_name              0
# stop_id                0
# total_ons              0
# total_offs             0
# number_service_days    0
# average_ons            0
# average_offs           0
# average_flow           0
# ObjectId               0
# dtype: int64
