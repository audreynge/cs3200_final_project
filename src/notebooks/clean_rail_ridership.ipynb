# %%
import pandas as pd
from pathlib import Path

# %%
df = pd.read_csv(Path('../../data/raw/rail_ridership.csv'))
df

"""
direction_id - 0 = outbound, 1 = inbound
"""
# Out:
# '\ndirection_id - 0 = outbound, 1 = inbound\n'

# %%
# drop unecessary cols
df = df.drop(columns=['route_name', 'day_type_id', 'time_period_id'], axis=1)

# %%
df
# Out:
#       mode     season route_id  direction_id day_type_name  \
# 0        0  Fall 2019    Green             0       weekday
# 1        0  Fall 2019    Green             0       weekday
# 2        0  Fall 2019    Green             0       weekday
# 3        0  Fall 2019    Green             0       weekday
# 4        0  Fall 2019    Green             0       weekday
# ...    ...        ...      ...           ...           ...
# 7915     1  Fall 2017      Red             0      saturday
# 7916     1  Fall 2017      Red             0      saturday
# 7917     1  Fall 2017      Red             0      saturday
# 7918     1  Fall 2017      Red             0      saturday
# 7919     1  Fall 2017      Red             0      saturday
#
#         time_period_name         stop_name      stop_id  total_ons  \
# 0     VERY_EARLY_MORNING    Allston Street  place-alsgr          0
# 1     VERY_EARLY_MORNING         Arlington  place-armnl       2675
# 2     VERY_EARLY_MORNING    Babcock Street  place-babck          0
# 3     VERY_EARLY_MORNING  Back of the Hill  place-bckhl          0
# 4     VERY_EARLY_MORNING      Beaconsfield  place-bcnfd         12
# ...                  ...               ...          ...        ...
# 7915            OFF_PEAK            Porter  place-portr      59366
# 7916            OFF_PEAK      Quincy Adams  place-qamnl        388
# 7917            OFF_PEAK     Quincy Center  place-qnctr       2128
# 7918            OFF_PEAK        Savin Hill  place-shmnl       2292
# 7919            OFF_PEAK           Shawmut  place-smmnl        657
#
#       total_offs  number_service_days  average_ons  average_offs  \
# 0             17                   77            0             0
# 1           8021                   77           35           104
# 2            151                   77            0             2
# 3             36                   77            0             0
# 4             67                   77            0             1
# ...          ...                  ...          ...           ...
# 7915        9940                   16         3710           621
# 7916       26507                   16           24          1657
# 7917       67000                   16          133          4188
# 7918       18338                   16          143          1146
# 7919       28253                   16           41          1766
#
#       average_flow  ObjectId
# 0                4         1
# 1              381         2
# 2                8         3
# 3                4         4
# 4               44         5
# ...            ...       ...
# 7915         13842      7916
# 7916          1549      7917
# 7917          3182      7918
# 7918          7237      7919
# 7919          3361      7920
#
# [7920 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# mode                   0
# season                 0
# route_id               0
# direction_id           0
# day_type_name          0
# time_period_id         0
# time_period_name       0
# stop_name              0
# stop_id                0
# total_ons              0
# total_offs             0
# number_service_days    0
# average_ons            0
# average_offs           0
# average_flow           0
# ObjectId               0
# dtype: int64
