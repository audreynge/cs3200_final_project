# %%
import pandas as pd
from pathlib import Path

# %%
df = pd.read_csv(Path('../../data/raw/bus_ridership.csv'))
df
# Out:
# /var/folders/_r/bzdphl5j26xf4tvws1yzvmv00000gn/T/ipykernel_96108/3574188395.py:1: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(Path('../../data/raw/bus_ridership.csv'))
#          mode     season route_id route_name route_variant  stop_sequence  \
# 0           3  Fall 2016        1          1         1-_-0             19
# 1           3  Fall 2016        1          1         1-_-0             20
# 2           3  Fall 2016        1          1         1-_-0             21
# 3           3  Fall 2016        1          1         1-_-0             22
# 4           3  Fall 2016        1          1         1-_-0             23
# ...       ...        ...      ...        ...           ...            ...
# 1086506     3  Fall 2024       99         99        99-7-1             31
# 1086507     3  Fall 2024       99         99        99-7-1             32
# ...

# %%
# drop unnecessary cols
df = df.drop(['mode', 'route_name', 'route_variant', 'stop_sequence', 'day_type_id', 'stop_name', 'ObjectId'], axis=1)

# %%
df
# Out:
#             season route_id  direction_id day_type_name  time_period_id  \
# 0        Fall 2016        1             0       weekday  time_period_06
# 1        Fall 2016        1             0       weekday  time_period_06
# 2        Fall 2016        1             0       weekday  time_period_06
# 3        Fall 2016        1             0       weekday  time_period_06
# 4        Fall 2016        1             0       weekday  time_period_06
# ...            ...      ...           ...           ...             ...
# 1086506  Fall 2024       99             1        sunday  time_period_11
# 1086507  Fall 2024       99             1        sunday  time_period_11
# 1086508  Fall 2024       99             1        sunday  time_period_11
# 1086509  Fall 2024       99             1        sunday  time_period_11
# 1086510  Fall 2024       99             1        sunday  time_period_11
#
#         time_period_name  stop_id  average_ons  average_offs  average_load  \
# ...
